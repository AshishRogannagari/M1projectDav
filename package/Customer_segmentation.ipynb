# %%
#import python libraries

import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt # visualizing data
# %matplotlib inline
import seaborn as sns

import Package.part2 as Ptwo
import Package.part3 as Pthree
import Package.part4 as Pfour

# %%
# importing csv file

df = pd.read_csv(r"https://raw.githubusercontent.com/AshishRogannagari/M1projectDav/main/Shopping_sales_Data.csv", encoding= 'unicode_escape')
df.shape
# Out:
# (11251, 15)

# %% [markdown]
# # Data summary

# %% [markdown]
# ### Setup and Context

# %% [markdown]
# - You are part of Customer Segmentation and have been approached by your client, the Category Manager , who wants to better understand the what types of customers are purchasing,what are they purchasing and what are there genders and where are their regions.

# %% [markdown]
#  ## Task
# - Data analysis and customer segments –
#  - in your analysis make sure you define the metrics
#  – look at total sales, drivers of sales, where the highest sales are coming from etc.
#  - Explore the data, create charts and graphs as well as noting any interesting trends and/or insights you find.

# %% [markdown]
# ## Business Metric

# %% [markdown]
# - Most sales from region
# - What marketing strategies could be effective for targeting this demographic group
# - category of transcation based on their order

# %% [markdown]
# ### Deep dive into customer segments
# -  Define your recommendation from your insights, determine which segments we should be targeting.

# %%
# Create an instance of the 'P2' class called 'p2' and pass a DataFrame 'df' as its data source.
p2 = Ptwo.P2(df)

# Call the 'data_sum' method on the 'p2' object.
# This method will compute the sum of data within the DataFrame 'df' and return the result.

p2.data_sum()
# Out:
# Data analysis and customer segments
# –in your analysis make sure you define the metrics
# – look at total sales, drivers of sales, where the highest sales are coming from etc.
# Explore the data, create charts and graphs as well as noting any interesting trends and/or insights you find.
# The Data set is about to sales transcations

# %% [markdown]
# # EDA

# %%
# Create an instance of the 'eda' class from the 'Pthree' module and name it 'p3'.
# This instance is initialized with the DataFrame 'df' to perform exploratory data analysis.

p3 = Pthree.eda(df)

# Call the 'Head' method on the 'p3' object with the argument '8'.
# This method is used to display the first 8 rows of the DataFrame 'df'.
# It helps us get an initial glimpse of the data in the dataset.

p3.Head(8)
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
# 5  1000588       Joni  P00057942      M     26-35   28               1
# 6  1001132       Balk  P00018042      F     18-25   25               1
# 7  1002092   Shivangi  P00273442      F       55+   61               0
#
#               State      Zone       Occupation Product_Category  Orders  \
# 0       Maharashtra   Western       Healthcare             Auto       1
# 1    Andhra Pradesh  Southern             Govt             Auto       3
# 2     Uttar Pradesh   Central       Automobile             Auto       3
# ...

# %%
# Call the 'Info' method on the 'p3' object.
# This method is used to obtain information about the DataFrame 'df' within the 'eda' instance 'p3'.

p3.Info()

# When you call 'Info', it provides essential details about the dataset, such as the number of rows and columns,
# data types, and information on missing values. This helps in understanding the structure and quality of the dataset.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age Group         11251 non-null  object
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  object
#  8   Zone              11251 non-null  object
#  9   Occupation        11251 non-null  object
#  10  Product_Category  11251 non-null  object
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
#  13  Status            0 non-null      float64
#  14  unnamed1          0 non-null      float64
# dtypes: float64(3), int64(4), object(8)
# memory usage: 1.3+ MB

# %%
#drop unrelated/blank columns

p3.drop_null_col()

# %%
# Call the 'display_dataframe' method on the 'p3' object.
# This method is used to display the entire DataFrame 'df' within the 'eda' instance 'p3'.

p3.display_dataframe()

# The 'display_dataframe' method will show the complete content of the dataset, allowing you to examine
# the data in detail. It's especially useful when you want to explore the entire dataset.
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28               0
# 1      1000732       Kartik  P00110942      F     26-35   35               1
# 2      1001990        Bindu  P00118542      F     26-35   35               1
# 3      1001425       Sudevi  P00237842      M      0-17   16               0
# 4      1000588         Joni  P00057942      M     26-35   28               1
# ...        ...          ...        ...    ...       ...  ...             ...
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
# ...

# %%
#check for null values

p3.check_null_sum()
# Out:
# User_ID              0
# Cust_name            0
# Product_ID           0
# Gender               0
# Age Group            0
# Age                  0
# Marital_Status       0
# State                0
# Zone                 0
# Occupation           0
# Product_Category     0
# Orders               0
# Amount              12
# dtype: int64

# %%
# drop null values

p3.drop_null()

# %%
# column_name() method returns the columns name of the data set.
p3.columns_names()
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
# describe() method returns description of the data in the DataFrame (i.e. count, mean, std, etc)
p3.Describe()
# Out:
#             User_ID           Age  Marital_Status        Orders        Amount
# count  1.123900e+04  11239.000000    11239.000000  11239.000000  11239.000000
# mean   1.003004e+06     35.410357        0.420055      2.489634   9453.610858
# std    1.716039e+03     12.753866        0.493589      1.114967   5222.355869
# min    1.000001e+06     12.000000        0.000000      1.000000    188.000000
# 25%    1.001492e+06     27.000000        0.000000      2.000000   5443.000000
# 50%    1.003064e+06     33.000000        0.000000      2.000000   8109.000000
# 75%    1.004426e+06     43.000000        1.000000      3.000000  12675.000000
# max    1.006040e+06     92.000000        1.000000      4.000000  23952.000000

# %%
# use describe() for specific columns
df[['Age', 'Orders', 'Amount']].describe()
# Out:
#                 Age        Orders        Amount
# count  11239.000000  11239.000000  11239.000000
# mean      35.410357      2.489634   9453.610858
# std       12.753866      1.114967   5222.355869
# min       12.000000      1.000000    188.000000
# 25%       27.000000      2.000000   5443.000000
# 50%       33.000000      2.000000   8109.000000
# 75%       43.000000      3.000000  12675.000000
# max       92.000000      4.000000  23952.000000

# %%
# describe specific column of order from the data
p3.Describe_column_name('Orders')
# Out:
# count    11239.000000
# mean         2.489634
# std          1.114967
# min          1.000000
# 25%          2.000000
# 50%          2.000000
# 75%          3.000000
# max          4.000000
# Name: Orders, dtype: float64

# %%
p3.Describe_column_name('Amount')
# Out:
# count    11239.000000
# mean      9453.610858
# std       5222.355869
# min        188.000000
# 25%       5443.000000
# 50%       8109.000000
# 75%      12675.000000
# max      23952.000000
# Name: Amount, dtype: float64

# %%
p3.Describe_column_name('Age')
# Out:
# count    11239.000000
# mean        35.410357
# std         12.753866
# min         12.000000
# 25%         27.000000
# 50%         33.000000
# 75%         43.000000
# max         92.000000
# Name: Age, dtype: float64

# %% [markdown]
# # Interference

# %% [markdown]
# ### Gender

# %%
# Create an instance of the 'Int' class from the 'Pfour' module and name it 'p4'.
# This instance is initialized with the DataFrame 'df' to perform various data visualization tasks.

p4 = Pfour.Int(df)

# By creating 'p4', you can use its methods to generate different types of data visualizations and insights
# based on the data in the DataFrame 'df'.

# %%
# Call the 'countplot_matplotlib' method on the 'p4' object with 'colname' set to 'Gender'.
# This method is used to create a bar chart using Matplotlib to visualize the count of 'Gender' categories.

p4.countplot_matplotlib(colname='Gender')

# The resulting bar chart will display the count of each 'Gender' category on the x-axis and the count itself
# on the y-axis. It helps in understanding the distribution of gender within the dataset.

# %%
# plotting a bar chart for Gender and it's count

p4.countplot(colname = 'Gender')

# %%
# plotting a bar chart for gender vs total amount

p4.barchart(x = 'Gender', y = 'Amount')

# %%
## plotting a matplotlib chart for gender vs total amount
p4.barchart_matplotlib(x = 'Gender', y = 'Amount')

# %% [markdown]
# *From above graphs we can see that most of the buyers are females and even the purchasing power of females are greater than men*

# %% [markdown]
# ### Age

# %%
## plotting a  chart for Age Group vs gender
p4.countplot(colname = 'Age Group', hue = 'Gender')

# %%
### plotting a matplotlib chart for Age Group vs gender
p4.countplot_matplotlib(colname = 'Age Group', hue = 'Gender')

# %%
# plotting chart for Total Amount vs Age Group

p4.barchart(x = 'Age Group', y = 'Amount')

# %%
#plotting a matplotlib chart for Age Group vs Amount
p4.barchart_matplotlib(x = 'Age Group', y = 'Amount')

# %% [markdown]
# *From above graphs we can see that most of the buyers are of age group between 26-35 yrs female*

# %% [markdown]
# ### State

# %%
# total number of orders for states

p4.barchart(x = 'State', y = 'Orders')

# %%
#plotting a matplotlib chart for State vs order
p4.barchart_matplotlib(x = 'State', y = 'Orders')

# %%
# total amount/sales from states

p4.barchart(x = 'State', y = 'Amount')

# %%
#plotting a matplotlib chart for state vs Amount
p4.barchart_matplotlib(x = 'State', y = 'Amount')

# %% [markdown]
# *From above graphs we can see that most of the orders & total sales/amount are from Uttar Pradesh, Maharashtra and Karnataka respectively*

# %% [markdown]
# ### Marital Status

# %%
# Marital status of gender 

p4.countplot(colname = 'Marital_Status')

# %%
## plotting a matplotlib chart for Marital status of gender 
p4.countplot_matplotlib(colname = 'Marital_Status')

# %% [markdown]
# *From above graphs we can see that most of the buyers are married (women) and they have high purchasing power*

# %% [markdown]
# ### Occupation

# %%
# bar char for Occupation & gender 
    
p4.countplot(colname = 'Occupation', hue = 'Gender')

# %%
#plotting a matplotlib chart for occupation and gender
p4.countplot_matplotlib(colname = 'Occupation', hue = 'Gender')

# %%
#plotting a bar chart for occupation and amount

p4.barchart(x = 'Occupation', y = 'Amount')

# %%
#plotting a matplotlib chart for occupation vs amount
p4.barchart_matplotlib(x = 'Occupation', y = 'Amount')

# %% [markdown]
# *From above graphs we can see that most of the buyers are working in IT, Healthcare and Aviation sector*

# %% [markdown]
# ### Product Category

# %%
#plotting a chart for coulumn product_category
    
p4.countplot(colname = 'Product_Category')

# %%
##plotting a matplotlib chart for column product_category
p4.countplot_matplotlib(colname = 'Product_Category')

# %%
#plotting a  chart for product_category vs amount

p4.barchart(x = 'Product_Category', y = 'Amount')

# %%
##plotting a matplotlib chart for product_category vs amount
p4.barchart_matplotlib(x = 'Product_Category', y = 'Amount')

# %% [markdown]
# *From above graphs we can see that most of the sold products are from Food, Clothing and Electronics category*

# %%
# creating a bar chart for product_category vs amount

p4.bar(x='Product_Category', y = 'Amount')

# %%
#creating a matplotlib chart for product_category vs amount
p4.bar_matplotlib(x='Product_Category', y = 'Amount')

# %%
# top 10 most sold products (same thing as above)

p4.bar(x='Product_ID', y = 'Orders')

# %%
## top 10 most sold products (same thing as above)
#plotting a matplotlib for product_id and orders
p4.bar_matplotlib(x='Product_ID', y = 'Orders')

# %% [markdown]
# ## Conclusion:
#
# ###

# %% [markdown]
# Absolutely, here's a more detailed breakdown:
#
# 1.Demographics: The data we are discussing is specifically about married women. This is an important distinction as it allows us to focus on a specific subset of the population.
#
# 2.Age Group: These women are within the age group of 26-35 years. This age bracket represents a significant portion of the working population and is often associated with a higher purchasing power due to stable employment.
#
# 3.Geographical Location: The women in this data set are from three states in India: Uttar Pradesh (UP), Maharashtra, and Karnataka. These states have diverse cultures and economies, which can influence purchasing behaviors.
#
# 4.Occupation: These women work in three key sectors: Information Technology (IT), Healthcare, and Aviation. These industries are known for their dynamic nature and often offer competitive salaries, which could influence the purchasing power of these women.
#
# 5.Purchasing Preferences: The data indicates that these women are more likely to purchase products from certain categories. Specifically, they tend to prefer items from the Food, Clothing, and Electronics categories. This information can be invaluable for businesses looking to target their products or marketing efforts towards this demographic.
#
# By understanding these points, we can gain a comprehensive view of the purchasing behaviors of married women aged 26-35 years from UP, Maharashtra, and Karnataka who work in the IT, Healthcare, and Aviation sectors. This information can be used to inform business strategies, marketing campaigns, product development, and more.

# %% [markdown]
# # References:

# %% [markdown]
#  Pandas :- https://pandas.pydata.org/
#  Matplotlib :- https://matplotlib.org/
#  Seaborn :- https://seaborn.pydata.org/
#  pandas read :- https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_csv.html
#
#  https://huggingface.co/docs/datasets/loading
#
#  https://www.geeksforgeeks.org/python-pandas-dataframe/
#
#  https://www.w3schools.com/python/python_lambda.asp
#
#  https://365datascience.com/resources-center/

# %% [markdown]
# Thank you!
